# %% [markdown]
# <!--- ![tu-dresden-blue.png](attachment:tu-dresden-blue.png) --->
# <img src="tu-dresden-blue.png" alt="drawing" width="200"/>
# <img src="ogs-teaching.png" alt="drawing" width="200"/>

# %% [markdown]
# Professur für Angewandte Umweltsystemanalyse an der TU Dresden <br/>
# Prof. Dr.-Ing. habil. Olaf Kolditz <br/>
# ***Hydroinformatik (UW-BHW-414)*** <br/>
# *[Lehre-Webseite](https://www.ufz.de/index.php?de=40425)*

# %% [markdown]
# ***Lena Hernschier***

# %% [markdown]
# ***Übung HA01: Skalarprodukt***

# %% [markdown]
# Schreiben sie das Skalarprodukt $\nabla\cdot\mathbf{v}$ in Komponentenschreibweise.}

# %% [markdown]
# $\nabla\cdot\mathbf{v}$ = $\frac{\partial v_x}{\partial x} + \frac{\partial v_y}{\partial y} + \frac{\partial v_z}{\partial z}$

# %% [markdown]
# ***Übung HA02: Kontinuumsmechanik***

# %% [markdown]
# Was ist $\mathbf v \cdot \nabla \psi$ ? <br/>
# Dieser Ausdruck ist ein Skalarprodukt ($\cdot$) des Geschwindigkeitsvektors ($\mathbf v = (v_x,v_y,v_z)$)
# mit dem Gradienten ($\nabla = (\partial/\partial x, \partial/\partial y, \partial/\partial z)$) einer skalaren Größe ($\psi$). <br/>
# In ausgeschriebener Form (Komponentenschreibweise) bedeutet der Ausdruck: <br/>
# $\mathbf v \cdot \nabla \psi
# =
# v_x \partial \psi/\partial x + v_y \partial \psi/\partial y + v_z \partial \psi/\partial z$
#
# Physiklalisch ist dieser Term der advektive Fluss der Größe $\psi$.

# %% [markdown]
# ***Übung HA03: Kontinuumsmechanik***

# %% [markdown]
# Was ist die physikalische Bedeutung des Terms $\Phi^\psi$?

# %% [markdown]
# ***Übung HA04: Kontinuumsmechanik***

# %% [markdown]
# Schreiben Sie den Ausdruck $\nabla \cdot (\mathbf v \psi)$ in Komponentenschreibweise.

# %% [markdown]
# $\frac{\partial}{\partial x}* v\psi + \frac{\partial}{\partial y}* v\psi + \frac{\partial}{\partial z}* v\psi $

# %% [markdown]
# ***Übung HA05: Kontinuumsmechanik***

# %% [markdown]
# Schreiben Sie den Ausdruck $\nabla \cdot (\mathbf D^\psi \nabla \psi)$ in Komponentenschreibweise.

# %% [markdown]
# ![image.png](attachment:4fa25d02-99a5-46eb-aa5b-cbeee7c3d971.png)

# %% [markdown]
# ***Übung HA06: Analytik***

# %% [markdown]
# Prüfen Sie die Gültigkeit folgender Lösungen für die Diffusionsgleichung:
# \begin{equation}
# \frac{\partial u}{\partial t} - \alpha \frac{\partial^2 u}{\partial x^2} = 0
# \end{equation}

# %% [markdown]
# \begin{equation}
# \psi(t,x) = sin (\sqrt{\pi\alpha} x) exp (-\pi t)
# \end{equation}
# \begin{equation}
# \psi(t,x) = sin (\frac{\pi}{\sqrt{\alpha}} x) exp (-\pi^2 t)
# \end{equation}
# \begin{equation}
# \psi(t,x) = sin (\pi x) exp (-\alpha\pi^2 t)
# \end{equation}

# %% [markdown]
# 1. Gleichung:
#
# \begin{equation}
# \frac{\partial\psi}{\partial t} = -\pi sin (\sqrt{\pi\alpha} x) exp (-\pi t)
# \end{equation}
# \begin{equation}
# \frac{\partial\psi}{\partial x} = \sqrt{\pi\alpha} cos (\sqrt{\pi\alpha} x) exp (-\pi t)
# \end{equation}
# \begin{equation}
# \frac{\partial^2\psi}{\partial x^2} = - \pi\alpha sin (\sqrt{\pi\alpha} x) exp (-\pi t)
# \end{equation}
# \begin{equation}
# \frac{\partial\psi}{\partial t} =! \alpha\frac{\partial^2\psi}{\partial x^2}
# \end{equation}
#
# 2. Gleichung
# \begin{equation}
# \frac{\partial\psi}{\partial t} = -\pi^2 sin (\frac{\pi}{\sqrt{\alpha}} x) exp (-\pi^2 t)
# \end{equation}
# \begin{equation}
# \frac{\partial\psi}{\partial x} = \frac{\pi}{\sqrt{\alpha}} cos (\frac{\pi}{\sqrt{\alpha}} x) exp (-\pi^2 t)
# \end{equation}
# \begin{equation}
# \frac{\partial^2\psi}{\partial x^2} = -\frac{\pi^2}{\alpha} sin (\frac{\pi}{\sqrt{\alpha}} x) exp (-\pi^2 t)
# \end{equation}
#
# \begin{equation}
# \frac{\partial\psi}{\partial t} = \alpha\frac{\partial^2\psi}{\partial x^2}
# \end{equation}
#
# 3. Gleichung
#
# \begin{equation}
# \frac{\partial\psi}{\partial t} = -\alpha\pi^2 sin (\pi x) exp (-\alpha\pi^2 t)
# \end{equation}
# \begin{equation}
# \frac{\partial\psi}{\partial x} = \pi cos (\pi x) exp (-\alpha\pi^2 t)
# \end{equation}
# \begin{equation}
# \frac{\partial^2\psi}{\partial x^2} = -\pi^2 sin (\pi x) exp (-\alpha\pi^2 t)
# \end{equation}
#
# \begin{equation}
# \frac{\partial\psi}{\partial t} = \alpha\frac{\partial^2\psi}{\partial x^2}
# \end{equation}

# %% [markdown]
# ***Übung HA07: Analytische Lösungen partieller Differentialgleichungen***

# %% [markdown]
# Lösen Sie die analytische Lösungen für die 1-D parabolische Differentialgleichung mit Hilfe von Python.

# %% [markdown]
# ***Übung HA07a***

# %% [markdown]
# Partial Differential Equation:
# $\frac{\partial u}{\partial t} - \alpha \frac{\partial^2 u}{\partial x^2} = 0$
#
# Initial condition:
# $u(t=0,x)=1$
#
# Boundary conditions
# $u(t,x=0)=0$
# $u(t,x=1)=0$

# %% [markdown]
# Partial Differential Equation:
# $\frac{\partial u}{\partial t} - \alpha \frac{\partial^2 u}{\partial x^2} = 0$
#
# Initial condition:
# $u(t=0,x)=1$
#
# Boundary conditions
# $u(t,x=0)=0$
# $u(t,x=1)=0$

# %%
import math
import matplotlib.pylab as plt
PI = 3.1415926
numPoints = 10
alpha = 1.0
t = [0.1,0.5,1.0,2.0]
x = []
y = []
for n in t:
    for i in range(0,numPoints+1):
        x.append(float(i)/float(numPoints))
        y.append(math.sin(math.sqrt(PI*alpha)*x[i]) * math.exp(-PI*n))
    plt.plot(x,y,color='red',marker="o")
    x = []
    y = []

plt.xlabel('x')
plt.ylabel('u')
plt.axis('tight')
plt.title('Lena Hernschier')
plt.show()

# %% [markdown]
# ***Übung HA07b***

# %% [markdown]
# 2. Gleichung (aus HA06)

# %%
import math
import matplotlib.pylab as plt
PI = 3.1415926
numPoints = 10
alpha = 1.0
t = [0.1,0.5,1.0,2.0]
x = []
y = []
for n in t:
    for i in range(0,numPoints+1):
        x.append(float(i)/float(numPoints))
        y.append(math.sin(PI*x[i]/math.sqrt(alpha)) * math.exp(-PI*PI*n))
    plt.plot(x,y,color='red',marker="o")
    x = []
    y = []

plt.xlabel('x')
plt.ylabel('u')
plt.axis('tight')
plt.title('Lena Hernschier')
plt.show()

# %% [markdown]
# ***Übung HA07c***

# %%
3. Gleichung (aus HA06)

# %%
import math
import matplotlib.pylab as plt
PI = 3.1415926
numPoints = 10
alpha = 1.0
t = [0.1,0.5,1.0,2.0]
x = []
y = []
for n in t:
    for i in range(0,numPoints+1):
        x.append(float(i)/float(numPoints))
        y.append(math.sin(PI*x[i]) * math.exp(-alpha*PI*PI*n))
    plt.plot(x,y,color='red',marker="o")
    x = []
    y = []

plt.xlabel('x')
plt.ylabel('u')
plt.axis('tight')
plt.title('Lena Hernschier')
plt.show()

# %% [markdown]
# ***Übung HA08: Numerische Lösung der Diffusiongleichung mit der expliziten Finiten-Differenzen-Methode***

# %%
import math
import numpy as np
import matplotlib.pylab as plt
#data structures
##physical parameter
alpha = 1.0
##numerical parameters (discretization)
nx = 100
x = np.zeros(nx+1)
dx = 1./nx
t = [0.01]
nt = 500 #wieviele Zeitschritte bis zum stationären Zustand
dt = 0.505 * dx*dx / alpha
Ne = alpha * dt / (dx*dx)
##field function
u = np.zeros(nx+1)
uo = np.zeros(nx+1)
#initial condition
u_ic = 0.
for i in range(nx+1):
	x[i] = 0
	u[i] = 0
	uo[i] = 0
#boundary conditions
u_bc_l = 3.
u_bc_r = -1.
u[0] = uo[0] = u_bc_l
u[nx] = uo[nx] = u_bc_r
#initial state
for i in range(0,nx+1):
    x[i] = (float(i)/float(nx))
plt.plot(x,u,color='blue')
#fdm-explicit
for n in range(1,nt):
	for i in range(1,nx):
		u[i] = uo[i] + Ne *(uo[i-1] - 2*uo[i] + uo[i+1])
	if(n % 10 == 0): 
	    plt.plot(x,u,color='blue')
	for i in range(1,nx):
		uo[i] = u[i]
#plots
plt.title('EX08: explizite Finite-Differenzen-Methode')
plt.xlabel('x')
plt.ylabel('u')
plt.axis('tight')
plt.grid()
plt.savefig("fdm-explicit.png")
plt.show()

# %% [markdown]
# ***Übung HA09: Numerische Lösung der Diffusiongleichung mit der impliziten Finiten-Differenzen-Methode***

# %%
# !g++ ifdm.cpp
# !a.exe
# Out:
# ifdm.cpp: In function 'int main(int, char**)':
# ifdm.cpp:97:30: error: 'Gauss' was not declared in this scope
#      Gauss(matrix,vecb,vecx,nj);
#                               ^
# Der Befehl "a.exe" ist entweder falsch geschrieben oder
# konnte nicht gefunden werden.

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('out.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x.append(float(row[0]))
        y.append(float(row[1]))

plt.plot(x,y, label='Data loaded from file: out.cvs')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Lena')
plt.legend()
plt.savefig("implizite_FDM.png")
plt.show()

# %% [markdown]
# ***Übung 10: Gerinnehydraulik***

# %%
#os.system("a.exe")
#Starten eines ausführbaren Programms aus einem Jupyter Notebook
# !g++ gerinnehydraulik.cpp
# !a.exe
# Out:
# 1.09429
# 0.837513
# 0.67501
# 0.562005
# 0.478426
# 0.413885
# 0.362434
# 0.320406
# 0.285409
# 0.255811
# 0.230456
# 0.208502
# 0.18932
# 0.172429
# 0.157454
# 0.144102
# 0.132133
# 0.121356
# 0.111613
# 0.102772
# 0.0947246
# 0.0873775
# 0.0806523
# 0.0744816
# 0.0688075
# 0.0635799
# 0.0587549
# 0.0542943
# 0.0501646
# 0.046336
# 0.0427821
# 0.0394797
# 0.0364077
# 0.0335474
# 0.0308821
# 0.0283965
# 0.0260769
# 0.023911
# 0.0218874
# 0.0199959
# 0.0182271
# 0.0165725
# 0.0150242
# 0.0135751
# 0.0122184
# 0.0109482
# 0.00975878
# 0.00864497
# 0.00760198
# 0.00662536
# 0.00317184
# 0.000644247
# 52

# %%
import matplotlib.pyplot as plt
import csv

x = []
y = []

with open('out.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        x.append(float(row[0]))
        y.append(float(row[1]))

plt.plot(x,y, label='Data loaded from file: out.cvs')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Hydroinformatics II (Olaf Kolditz)\nExercise BHYWI-08-11-for-python\nNewton-Verfahren Gerinnehydraulik')
plt.legend()
plt.savefig("gerinne.png")
plt.show()
