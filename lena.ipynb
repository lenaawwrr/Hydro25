# %% [markdown]
# <!--- ![tu-dresden-blue.png](attachment:tu-dresden-blue.png) --->
# <img src="tu-dresden-blue.png" alt="drawing" width="200"/>
# <img src="ogs-teaching.png" alt="drawing" width="200"/>

# %% [markdown]
# Professur für Angewandte Umweltsystemanalyse an der TU Dresden <br/>
# Prof. Dr.-Ing. habil. Olaf Kolditz <br/>
# ***Hydroinformatik (UW-BHW-414)*** <br/>
# *[Lehre-Webseite](https://www.ufz.de/index.php?de=40425)*

# %% [markdown]
# ***Lena Hernschier***

# %% [markdown]
# ***Übung HA01: Kontinuumsmechanik***

# %% [markdown]
# Was ist $\mathbf v \cdot \nabla \psi$ ? <br/>
# Dieser Ausdruck ist ein Skalarprodukt ($\cdot$) des Geschwindigkeitsvektors ($\mathbf v = (v_x,v_y,v_z)$)
# mit dem Gradienten ($\nabla = (\partial/\partial x, \partial/\partial y, \partial/\partial z)$) einer skalaren Größe ($\psi$). <br/>
# In ausgeschriebener Form (Komponentenschreibweise) bedeutet der Ausdruck: <br/>
# $\mathbf v \cdot \nabla \psi
# =
# v_x \partial \psi/\partial x + v_y \partial \psi/\partial y + v_z \partial \psi/\partial z$

# %% [markdown]
# ***Übung HAXY: Partielle Diferenzialgleichungen***

# %% [markdown]
# Partial Differential Equation:
# $\frac{\partial u}{\partial t} - \alpha \frac{\partial^2 u}{\partial x^2} = 0$
#
# Initial condition:
# $u(t=0,x)=1$
#
# Boundary conditions
# $u(t,x=0)=0$
# $u(t,x=1)=0$

# %% [markdown]
# Partial Differential Equation:
# $\frac{\partial u}{\partial t} - \alpha \frac{\partial^2 u}{\partial x^2} = 0$
#
# Initial condition:
# $u(t=0,x)=1$
#
# Boundary conditions
# $u(t,x=0)=0$
# $u(t,x=1)=0$

# %%
import math
import matplotlib.pylab as plt
PI = 3.1415926
numPoints = 10
alpha = 1.0
t = [0.1,0.5,1.0,2.0]
x = []
y = []
for n in t:
    for i in range(0,numPoints+1):
        x.append(float(i)/float(numPoints))
        y.append(math.sin(PI*x[i]) * math.exp(-alpha*n*n))
    plt.plot(x,y,color='red',marker="o")
    x = []
    y = []

plt.xlabel('x')
plt.ylabel('u')
plt.axis('tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 import math
# ----> 2 import matplotlib.pylab as plt
#       3 PI = 3.1415926
#       4 numPoints = 10
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# ***Übung HA05: Kontinuumsmechanik***
#
# $D_x \frac{\partial^2 \psi}{\partial x^2} + D_y \frac{\partial^2 \psi}{\partial y^2} + D_z \frac{\partial^2 \psi}{\partial z^2}$

# %% [markdown]
# ***Übung HA06: Analytik***
#
# Prüfen Sie die Gültikgeit folgender Lösungen für die Diffusionsgleichung: ...

# %% [markdown]
# (1) erste Funktion passt nicht

# %% [markdown]
# (2)

# %% [markdown]
# (3)
#
# $\frac{\partial\psi}{\partial t} = -\alpha\pi^2\sin(\pi x)\exp^{-\alpha\pi^2 t}$
#
# $\frac{\partial\psi}{\partial x} = \cos(\pi x)\pi\exp^{-\alpha\pi^2 t}$
#
# $\alpha\frac{\partial^2\psi}{\partial x^2} = -\alpha\pi^2\sin(\pi x)\exp^{-\alpha\pi^2 t}$

# %% [markdown]
# ***HA07***

# %%
import math
import matplotlib.pylab as plt
PI = 3.14
numPoints = 10
alpha = 1.0
t = [0.1,0.2,0.5,1.0,1.5,2.0]
x = []
y = []
for n in t:
    for i in range(0,numPoints+1):
        x.append(float(i)/float(numPoints))
        y.append(math.sin(PI*x[i]) * math.exp(-alpha*PI*PI*n))
    plt.plot(x,y,color='red',marker='o')
    x = []
    y = []
plt.xlabel('x')
plt.ylabel('u')
plt.axis('tight')
plt.show()

# %% [markdown]
# ***EX08: explizite Finite-Differenzen-Methode***

# %%
import math
import numpy as np
import matplotlib.pylab as plt
#data structures
##physical parameter
alpha = 1.0
##numerical parameters (discretization)
nx = 100
x = np.zeros(nx+1)
dx = 1./nx
t = [0.01]
nt = 500 #wieviele Zeitschritte bis zum stationären Zustand
dt = 0.505 * dx*dx / alpha
Ne = alpha * dt / (dx*dx)
##field function
u = np.zeros(nx+1)
uo = np.zeros(nx+1)
#initial condition
u_ic = 0.
for i in range(nx+1):
	x[i] = 0
	u[i] = 0
	uo[i] = 0
#boundary conditions
u_bc_l = 3.
u_bc_r = -1.
u[0] = uo[0] = u_bc_l
u[nx] = uo[nx] = u_bc_r
#initial state
for i in range(0,nx+1):
    x[i] = (float(i)/float(nx))
plt.plot(x,u,color='blue')
#fdm-explicit
for n in range(1,nt):
	for i in range(1,nx):
		u[i] = uo[i] + Ne *(uo[i-1] - 2*uo[i] + uo[i+1])
	if(n % 10 == 0): 
	    plt.plot(x,u,color='blue')
	for i in range(1,nx):
		uo[i] = u[i]
#plots
plt.title('EX08: explizite Finite-Differenzen-Methode')
plt.xlabel('x')
plt.ylabel('u')
plt.axis('tight')
plt.grid()
plt.savefig("fdm-explicit.png")
plt.show()
